# %%
import pandas as pd
top_movies=pd.read_csv(r"C:\Users\2021\Downloads\imdb_top_1000.csv")
top_movies
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
top_movies.dropna()
top_movies.dropna(axis="columns")
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year  Runtime  \
# 0    The Shawshank Redemption          1994  142 min
# 1               The Godfather          1972  175 min
# 2             The Dark Knight          2008  152 min
# 3      The Godfather: Part II          1974  202 min
# ...

# %%
top_genre=top_movies.Genre.value_counts().idxmax()
top_genre
# Out:
# 'Drama'

# %%
count_of_movies= pd.DataFrame(top_movies.Genre.value_counts())
count_of_movies
# Out:
#                            Genre
# Drama                         85
# Drama, Romance                37
# Comedy, Drama                 35
# Comedy, Drama, Romance        31
# Action, Crime, Drama          30
# ...                          ...
# Adventure, Thriller            1
# Animation, Action, Sci-Fi      1
# Action, Crime, Comedy          1
# Animation, Crime, Mystery      1
# Adventure, Comedy, War         1
#
# [202 rows x 1 columns]

# %%
import matplotlib.pyplot as pt
count_of_movies=count_of_movies.drop(count_of_movies.index[40:202])
count_of_movies.plot.bar()
pt.xlabel('genres')
pt.ylabel('count of movies/TV shows')
pt.show()

# %% [markdown]
# in the bar chart we know that the drama genre is the most popluar genre but since we have a lot of genres the bar chart
# doesn't cleary show their names. so i tried my best to drop most of the genres to see the bar chart clearly because we can't
# really deal with them and zoom in and out like excel

# %%
movies_by_director=pd.DataFrame(top_movies.Director.value_counts())
print(movies_by_director)
print("director with the most top-rated movies/TV shows is: ",movies_by_director.idxmax())
# Out:
#                   Director
# Alfred Hitchcock        14
# Steven Spielberg        13
# Hayao Miyazaki          11
# Martin Scorsese         10
# Akira Kurosawa          10
# ...                    ...
# Neill Blomkamp           1
# Tomas Alfredson          1
# Duncan Jones             1
# Jacques Audiard          1
# George Stevens           1
#
# [548 rows x 1 columns]
# director with the most top-rated movies/TV shows is:  Director    Alfred Hitchcock
# dtype: object

# %%
movies_by_director=movies_by_director.drop(movies_by_director.index[40:548])
movies_by_director.plot.bar()
pt.xlabel('directors')
pt.ylabel('count of movies')
pt.show()

# %% [markdown]
# i tried the same thing with the bar chart here to drop some rows to make them clear to observe

# %% [markdown]
# as a result, we observed that the drama genre is the most popular genre in which it has the most count of movies and tv shows
# the highest ratings from the viewers since we have more than 80 movies and tv shows in our dataset.
# moving on to our top rated movies and shows we observe that Alfred Hitchcock had the highest number of movies directed by him,
# followed by steven spielberg.
